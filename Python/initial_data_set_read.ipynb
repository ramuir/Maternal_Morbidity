# %%
import pandas as pd 
import numpy as np
import os

# %%
variables_df = pd.read_excel("../Data_Sets/nuMoM2b_Codebook_NICHD Data Challenge.xlsx", header=1, sheet_name = 0)

# %%
code_lists_df = pd.read_excel("../Data_Sets/nuMoM2b_Codebook_NICHD Data Challenge.xlsx", header=1, sheet_name = 1)

# %%
glbl_indicator_df = pd.read_excel("../Data_Sets/nuMoM2b_Codebook_NICHD Data Challenge.xlsx", header=1, sheet_name = 2, usecols = 'A,B', skiprows = lambda x: x not in [0,1, 2,3,4,5,6])

# %%
variables_df
# Out:
#       Original Dataset Name   Variable Name  \
# 0                       NaN        PublicID
# 1                       a02    A02_Complete
# 2                       a02  A02_Complete_1
# 3                       a02      A02_Status
# 4                       a02    A02_Status_1
# ...                     ...             ...
# 11612                   vxx     VXXC01j_045
# 11613                   vxx     VXXC01k_045
# 11614                   vxx         VXXC02a
# 11615                   vxx         VXXC02b
# 11616                   vxx         VXXC02c
#
#                                           Variable Label Variable Type  \
# 0                                      Public nuMoM2b ID     Character
# 1                                (A02) Data entry status     Character
# 2                                (A02) Data entry status     Character
# 3                                (A02) Validation status     Character
# 4                                (A02) Validation status     Character
# ...

# %%
code_lists_df
# Out:
#       Activity_Code  1   Aerobics Class/Exercise Machines
# 0     Activity_Code  2                         Basketball
# 1     Activity_Code  3                            Bowling
# 2     Activity_Code  4  Calisthenics/Home or Gym Exercise
# 3     Activity_Code  5            Canoeing/Rowing/Sailing
# 4     Activity_Code  6                            Cycling
# ...             ... ..                                ...
# 1539     Yes_No_v10  2                   Yes, temporarily
# 1540     Yes_No_v10  3                                 No
# 1541       Zygosity  1               Present heterozygote
# 1542       Zygosity  2                 Present homozygote
# 1543       Zygosity  3                             Absent
#
# [1544 rows x 3 columns]

# %%
glbl_indicator_df
# Out:
#         Value   Value Label
# 0  Blank or M       Missing
# 1     -8 or D    Don't know
# 2     -7 or R       Refused
# 3           S  Skip pattern
# 4           E    Form error
